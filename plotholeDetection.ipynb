# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarshthakur-850/plotholeDetection/blob/main/plotholeDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import files
from PIL import Image
import numpy as np

def detect_road_damage(image_path):

  damage_type = "Pothole"
  confidence = 0.8
  bounding_box = [100, 100, 200, 200]

  return {'damage_type': damage_type, 'confidence': confidence, 'bounding_box': bounding_box}



uploaded = files.upload()

for filename in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=filename, length=len(uploaded[filename])))

  image_path = filename
  image = Image.open(image_path)
  results = detect_road_damage(image_path)

  print(f"Damage Type: {results['damage_type']}")
  print(f"Confidence: {results['confidence']}")
  print(f"Bounding Box: {results['bounding_box']}")
# Out:
#      <input type="file" id="files-3e68e83b-c988-443c-a2af-c4239e52e225" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e68e83b-c988-443c-a2af-c4239e52e225">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
from google.colab import files
from PIL import Image
import numpy as np


def detect_road_damage(image_path):

  try:
      image = Image.open(image_path)
      width, height = image.size
      if width > 200 and height > 200:
          damage_type = "Crack"
      else:
          damage_type = "Pothole"
      confidence = 0.8
      bounding_box = [100, 100, 200, 200]
  except Exception as e:
      print(f"Error processing image: {e}")
      return {'damage_type': 'Unknown', 'confidence': 0.0, 'bounding_box': [0, 0, 0, 0]}

  return {'damage_type': damage_type, 'confidence': confidence, 'bounding_box': bounding_box}


uploaded = files.upload()

for filename in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=filename, length=len(uploaded[filename])))

  image_path = filename

  results = detect_road_damage(image_path)

  print(f"Damage Type: {results['damage_type']}")
  print(f"Confidence: {results['confidence']}")
  print(f"Bounding Box: {results['bounding_box']}")
# Out:
#      <input type="file" id="files-26713d1e-53b4-4f13-969e-97dd2b2c0489" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26713d1e-53b4-4f13-969e-97dd2b2c0489">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
from google.colab import files
from PIL import Image
import numpy as np

def detect_road_damage(image_path):
  try:
      image = Image.open(image_path)
      width, height = image.size\
      if width > height:
          damage_type = "Crack"
      else:
          damage_type = "Pothole"
      confidence = 0.8
      bounding_box = [100, 100, 200, 200]
  except Exception as e:
      print(f"Error processing image: {e}")
      return {'damage_type': 'Unknown', 'confidence': 0.0, 'bounding_box': [0, 0, 0, 0]}

  return {'damage_type': damage_type, 'confidence': confidence, 'bounding_box': bounding_box}

uploaded = files.upload()

for filename in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=filename, length=len(uploaded[filename])))

  image_path = filename
  results = detect_road_damage(image_path)

  print(f"Damage Type: {results['damage_type']}")
  print(f"Confidence: {results['confidence']}")
  print(f"Bounding Box: {results['bounding_box']}")
# Out:
#      <input type="file" id="files-fc20716a-d507-4a0c-99ee-3e6ce957cf3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc20716a-d507-4a0c-99ee-3e6ce957cf3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
